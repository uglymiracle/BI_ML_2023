# %% [markdown]
# Всем привет! Сегодня вы впервые попробуете написать свою собственную нейронную сеть и попробовать ее обучить. Мы будем работать с картинками, но пока что не совсем тем способом, которым лучше всего это делать, но должно получиться неплохо.
#
# Будем работать с [датасетом](https://github.com/rois-codh/kmnist) `Kuzushiji-MNIST` (`KMNIST`). Это рукописные буквы, изображения имеют размер (28, 28, 1) и разделены на 10 классов, по ссылке можно прочитать подробнее.

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Сейчас мы будем использовать встроенные данные, но в реальности приходится писать свой класс для датасета (Dataset), у которого реализовывать несколько обязательных методов (напр, `__getitem__`), но это обсудим уже потом.

# %%
import torchvision
from torchvision.datasets import KMNIST


# Превращает картинки в тензоры
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()])

# Загрузим данные (в переменных лежат объекты типа `Dataset`)
# В аргумент `transform` мы передаем необходимые трансформации (ToTensor)
trainset = KMNIST(root="./KMNIST", train=True, download=True, transform=transform)
testset = KMNIST(root="./KMNIST", train=False, download=True, transform=transform)

clear_output()

# %% [markdown]
# Определим даталоадеры, они нужны, чтобы реализовывать стохастический градиентный спуск (то есть мы не хотим считывать в оперативную память все картинки сразу, а делать это батчами).

# %%
from torch.utils.data import DataLoader


# Можно оставить таким
batch_size = 256

trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# %% [markdown]
# Подумайте, как может влиять на скорость обучения параметр `batch_size`, почему вы так считаете?
#
# **Ответ:**
#
# С увеличением `batch_size` скорость обучения будет снижаться, так как быстрее будет находиться минимум и меньше будет шагов в ненужные стороны

# %% [markdown]
# Посмотрим на какую-нибудь картинку:

# %%
plt.imshow(trainset[0][0].view(28, 28).numpy(), cmap="gray")
plt.axis("off")
plt.title(f"Class is {trainset[0][1]}", fontsize=16);

# %% [markdown]
# ### Задание 1. Смотрим на картинки
#
# **2** балла
#
# Нарисуйте на одном графике изображения всех 10 классов:

# %% [markdown]
# ⣿⣿⣿⣿⣿⣿⠿⢋⣥⣴⣶⣶⣶⣬⣙⠻⠟⣋⣭⣭⣭⣭⡙⠻⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⡿⢋⣴⣿⣿⠿⢟⣛⣛⣛⠿⢷⡹⣿⣿⣿⣿⣿⣿⣆⠹⣿⣿⣿⣿
# ⣿⣿⣿⡿⢁⣾⣿⣿⣴⣿⣿⣿⣿⠿⠿⠷⠥⠱⣶⣶⣶⣶⡶⠮⠤⣌⡙⢿⣿
# ⣿⡿⢛⡁⣾⣿⣿⣿⡿⢟⡫⢕⣪⡭⠥⢭⣭⣉⡂⣉⡒⣤⡭⡉⠩⣥⣰⠂⠹
# ⡟⢠⣿⣱⣿⣿⣿⣏⣛⢲⣾⣿⠃⠄⠐⠈⣿⣿⣿⣿⣿⣿⠄⠁⠃⢸⣿⣿⡧
# ⢠⣿⣿⣿⣿⣿⣿⣿⣿⣇⣊⠙⠳⠤⠤⠾⣟⠛⠍⣹⣛⣛⣢⣀⣠⣛⡯⢉⣰
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡶⠶⢒⣠⣼⣿⣿⣛⠻⠛⢛⣛⠉⣴⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⡿⢛⡛⢿⣿⣿⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡈⢿⣿
# ⣿⣿⣿⣿⣿⣿⣿⠸⣿⡻⢷⣍⣛⠻⠿⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⢇⡘⣿
# ⣿⣿⣿⣿⣿⣿⣿⣷⣝⠻⠶⣬⣍⣛⣛⠓⠶⠶⠶⠤⠬⠭⠤⠶⠶⠞⠛⣡⣿
# ⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣬⣭⣍⣙⣛⣛⣛⠛⠛⠛⠿⠿⠿⠛⣠⣿⣿
# ⣦⣈⠉⢛⠻⠿⠿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠛⣁⣴⣾⣿⣿⣿⣿
# ⣿⣿⣿⣶⣮⣭⣁⣒⣒⣒⠂⠠⠬⠭⠭⠭⢀⣀⣠⣄⡘⠿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⡈⢿⣿⣿⣿⣿⣿

# %%
r = 0

for k in range(10):

    while trainset[r][1] != k:
        r += 1

    plt.subplot(2, 5, k+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(trainset[r][0].view(28, 28).numpy(), cmap="gray")
    plt.axis("off")
    plt.title(f"Class is {trainset[r][1]}", fontsize=16);

# %% [markdown]
# ### Задание 2. Строим свой первый MLP
#
# **4** балла
#
# MLP (multilayer perceptron) или нейронная сеть из полносвязных (линейных) слоев, это мы уже знаем.
#
# Опишите структуру сети: 3 полносвязных слоя + функции активации на ваш выбор. **Подумайте** про активацию после последнего слоя!
#
# Сеть на выходе 1 слоя должна иметь 256 признаков, на выходе из 2 128 признаков, на выходе из последнего столько, сколько у вас классов.
#
# https://pytorch.org/docs/stable/nn.html?highlight=activation#non-linear-activations-weighted-sum-nonlinearity

# %%
import torch.nn as nn
import torch.nn.functional as F

class FCNet(nn.Module):
    def __init__(self):
        super().__init__() #  это надо помнить!
        self.fc1 = nn.Linear(in_features=28*28, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=128)
        self.fc3 = nn.Linear(in_features=128, out_features=10)

    def forward(self, x):  # Forward вызывается внутри метода __call__ родительского класса
        ## x -> тензор размерности (BATCH_SIZE, N_CHANNELS, WIDTH, HEIGHT)
        ## надо подумать над тем, что у нас полносвязные слои принимают векторы

        x = x.view(-1, 28*28) # переведем картинку в вектор
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        logits = self.fc3(x)

        return logits

# %% [markdown]
# Сколько обучаемых параметров у вашей модели (весов и смещений)?
#
# **Ответ:**

# %%
print('весов = ',28*28*256 + 256*128 + 128*10)
print('смещений = ', 256 + 128 + 10)
print('n_параметров = ', 28*28*256 + 256*128 + 128*10 + 256 + 128 + 10)
# Out:
# весов =  234752
# смещений =  394
# n_параметров =  235146

# %% [markdown]
# ### Задание 3. Напишите код для обучения модели
#
# **5** баллов
#
# Можно (и нужно) подглядывать в код семинара по пайторчу. Вам нужно создать модель, определить функцию потерь и оптимизатор (начнем с `SGD`). Дальше нужно обучать модель, при помощи тренировочного `Dataloader'a` и считать лосс на тренировочном и тестовом `Dataloader'ах`.

# %% [markdown]
# Напишем функцию для рассчета `accuracy`:

# %%
def get_accuracy(model, dataloader):
    """
    model - обученная нейронная сеть
    dataloader - даталоадер, на котором вы хотите посчитать accuracy
    """
    correct = 0
    total = 0
    with torch.no_grad(): # Тензоры внутри этого блока будут иметь requires_grad=False
        for images, labels in dataloader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total
    
    return accuracy

# %% [markdown]
# #### Основной цикл обучения
#
# Этот код можно (и зачастую нужно) выносить в отдельную функцию, но пока что можете это не делать, все по желанию)

# %%
# Создадим объект модели
fc_net = FCNet()
# Определим функцию потерь
loss_function = nn.CrossEntropyLoss()
# Создадим оптимизатор для нашей сети
lr = 0.001 # скорость обучения
optimizer = torch.optim.Adam(fc_net.parameters(), lr=3e-4)

# %% [markdown]
# Напишите цикл обучения. Для начала хватит 10 эпох. Какое значение `accuracy` на тестовой выборке удалось получить?

# %%
n_epochs = 10
loss_history = []

for epoch in range(n_epochs):
    epoch_loss = 0
    for images, labels in trainloader: 
        optimizer.zero_grad() 
        outputs = fc_net(images) 
        loss = loss_function(outputs, labels) 
        loss.backward() 
        optimizer.step() 

        epoch_loss += loss.item()

    loss_history.append(epoch_loss/len(trainloader))

    print(f"Epoch={epoch+1} loss={loss_history[epoch]:.4f}")
# Out:
# Epoch=1 loss=0.9205
# Epoch=2 loss=0.4537
# Epoch=3 loss=0.3565
# Epoch=4 loss=0.2964
# Epoch=5 loss=0.2527
# Epoch=6 loss=0.2180
# Epoch=7 loss=0.1914
# Epoch=8 loss=0.1670
# Epoch=9 loss=0.1476
# Epoch=10 loss=0.1311

# %%
 get_accuracy(fc_net, testloader)
# Out:
# 0.8695

# %% [markdown]
# ### Задание 4. Изучение влияния нормализации
#
# **3** балла
#
# Вы могли заметить, что мы забыли провести нормализацию наших данных, а для нейронных сетей это может быть очень критично.
#
# Нормализуйте данные.
#
# * Подсчитайте среднее значение и стандартное отклонение интенсивности пикселей для всех тренировочных данных
# * Нормализуйте данные с использованием этих параметров (используйте трансформацию `Normalize`)
#
#
# Оцените влияние нормировки данных.

# %%
images, lebels = next(iter(trainloader))
mean, std = images.mean([0,2,3]), images.std([0,2,3])
print(mean, std)

transform_with_norm = torchvision.transforms.Compose([
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize(mean, std)
            ])

trainset.transform = transform_with_norm 
testset.transform = transform_with_norm
# Out:
# tensor([0.1993]) tensor([0.3546])

# %%
fc_net = FCNet()
loss_function = nn.CrossEntropyLoss()
lr = 0.001
optimizer = torch.optim.Adam(fc_net.parameters(), lr=3e-4)

# %%
n_epochs = 10
loss_history = []

for epoch in range(n_epochs):
    epoch_loss = 0
    for images, labels in trainloader: 
        optimizer.zero_grad() 
        outputs = fc_net(images) 
        loss = loss_function(outputs, labels) 
        loss.backward() 
        optimizer.step() 

        epoch_loss += loss.item()

    loss_history.append(epoch_loss/len(trainloader))

    print(f"Epoch={epoch+1} loss={loss_history[epoch]:.4f}")
# Out:
# Epoch=1 loss=0.6868
# Epoch=2 loss=0.3038
# Epoch=3 loss=0.2246
# Epoch=4 loss=0.1742
# Epoch=5 loss=0.1397
# Epoch=6 loss=0.1153
# Epoch=7 loss=0.0942
# Epoch=8 loss=0.0759
# Epoch=9 loss=0.0629
# Epoch=10 loss=0.0507

# %%
get_accuracy(fc_net, testloader)
# Out:
# 0.8926

# %% [markdown]
# Как изменилась `accuracy` после нормализации?

# %% [markdown]
# немножечко повысилась

# %% [markdown]
# ### Задание 5. Изучение влияния функции активации
#
# **3** балла
#
# Исследуйте влияние функций активации на скорость обучения и точность предсказаний модели.
#
# Используйте три функции:
#
# * [Sigmoid](https://pytorch.org/docs/stable/nn.functional.html#sigmoid)
# * [GELU](https://pytorch.org/docs/stable/nn.functional.html#gelu)
# * [Tanh](https://pytorch.org/docs/stable/generated/torch.nn.Tanh.html#torch.nn.Tanh)

# %%
from torch.nn.modules import activation
class FCNet(nn.Module):
    def __init__(self, activation):
        super().__init__() #  это надо помнить!
        self.fc1 = nn.Linear(in_features=28*28, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=128)
        self.fc3 = nn.Linear(in_features=128, out_features=10)
        self.activation = activation

    def forward(self, x):  # Forward вызывается внутри метода __call__ родительского класса
        ## x -> тензор размерности (BATCH_SIZE, N_CHANNELS, WIDTH, HEIGHT)
        ## надо подумать над тем, что у нас полносвязные слои принимают векторы

        x = x.view(-1, 28*28) # переведем картинку в вектор
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        x = self.activation(x)
        logits = self.fc3(x)

        return logits

# %%
activations = [nn.ReLU(), nn.Sigmoid(), nn.GELU(), nn.Tanh()]
accurs = []

for activation in activations:
    # Создадим объект модели
    fc_net = FCNet(activation = activation)
    # Определим функцию потерь
    loss_function = nn.CrossEntropyLoss()
    # Создадим оптимизатор для нашей сети
    lr = 0.001 # скорость обучения
    optimizer = torch.optim.Adam(fc_net.parameters(), lr=3e-4)

    n_epochs = 10
    loss_history = []

    for epoch in range(n_epochs):
        epoch_loss = 0
        for images, labels in trainloader: 
            optimizer.zero_grad() 
            outputs = fc_net(images) 
            loss = loss_function(outputs, labels) 
            loss.backward() 
            optimizer.step() 

            epoch_loss += loss.item()

        loss_history.append(epoch_loss/len(trainloader))

        print(f"Epoch={epoch+1} loss={loss_history[epoch]:.4f}")

    accurs.append(get_accuracy(fc_net, testloader))


for i in range(len(accurs)):
    print(f'Activation "{activations[i]}" is {accurs[i]}')
# Out:
# Epoch=1 loss=0.6925
# Epoch=2 loss=0.3037
# Epoch=3 loss=0.2222
# Epoch=4 loss=0.1718
# Epoch=5 loss=0.1376
# Epoch=6 loss=0.1114
# Epoch=7 loss=0.0920
# Epoch=8 loss=0.0751
# Epoch=9 loss=0.0609
# Epoch=10 loss=0.0508
# Epoch=1 loss=1.5634
# Epoch=2 loss=0.7527
# Epoch=3 loss=0.5419
# Epoch=4 loss=0.4419
# Epoch=5 loss=0.3731
# Epoch=6 loss=0.3206
# Epoch=7 loss=0.2786
# Epoch=8 loss=0.2436
# Epoch=9 loss=0.2145
# Epoch=10 loss=0.1899
# Epoch=1 loss=0.6619
# Epoch=2 loss=0.2854
# Epoch=3 loss=0.2051
# Epoch=4 loss=0.1565
# Epoch=5 loss=0.1230
# Epoch=6 loss=0.0985
# Epoch=7 loss=0.0785
# Epoch=8 loss=0.0637
# Epoch=9 loss=0.0498
# Epoch=10 loss=0.0397
# Epoch=1 loss=0.7785
# Epoch=2 loss=0.3862
# Epoch=3 loss=0.2591
# Epoch=4 loss=0.1857
# Epoch=5 loss=0.1373
# Epoch=6 loss=0.1048
# Epoch=7 loss=0.0788
# Epoch=8 loss=0.0589
# Epoch=9 loss=0.0445
# Epoch=10 loss=0.0320
# Activation "ReLU()" is 0.8944
# Activation "Sigmoid()" is 0.8538
# Activation "GELU(approximate='none')" is 0.9023
# Activation "Tanh()" is 0.9016

# %% [markdown]
# С использованием какой функции активации удалось досчить наибольшей `accuracy`?

# %% [markdown]
# GELU показывает лучшие результаты с очень маленьким отрывом

# %% [markdown]
# ### Задание 6. Другие оптимизаторы
#
# **4** балла
#
# Исследуйте влияние оптимизаторов на скорость обучения и точность предсказаний модели.
#
# Попробуйте следующие:
#
# * [Adam](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html#torch.optim.Adam)
# * [RMSprop](https://pytorch.org/docs/stable/generated/torch.optim.RMSprop.html#torch.optim.RMSprop)
# * [Adagrad](https://pytorch.org/docs/stable/generated/torch.optim.Adagrad.html#torch.optim.Adagrad)
#
# Вам нужно снова обучить 3 модели и сравнить их перформанс (функцию активации используйте ту, которая показала себя лучше всего).

# %%
optimizers = [torch.optim.Adam, torch.optim.RMSprop, torch.optim.Adagrad]
accurs = []

for optim in optimizers:
    # Создадим объект модели
    fc_net = FCNet(activation = nn.GELU())
    # Определим функцию потерь
    loss_function = nn.CrossEntropyLoss()
    # Создадим оптимизатор для нашей сети
    lr = 0.001 # скорость обучения
    optimizer = optim(fc_net.parameters(), lr=3e-4)

    n_epochs = 10
    loss_history = []

    for epoch in range(n_epochs):
        epoch_loss = 0
        for images, labels in trainloader: 
            optimizer.zero_grad() 
            outputs = fc_net(images) 
            loss = loss_function(outputs, labels) 
            loss.backward() 
            optimizer.step() 

            epoch_loss += loss.item()

        loss_history.append(epoch_loss/len(trainloader))

        print(f"Epoch={epoch+1} loss={loss_history[epoch]:.4f}")

    accurs.append(get_accuracy(fc_net, testloader))


for i in range(len(accurs)):
    print(f'Optimizer "{optimizers[i]}" has accuracy {accurs[i]}')
# Out:
# Epoch=1 loss=0.6543
# Epoch=2 loss=0.2873
# Epoch=3 loss=0.2103
# Epoch=4 loss=0.1597
# Epoch=5 loss=0.1260
# Epoch=6 loss=0.1007
# Epoch=7 loss=0.0813
# Epoch=8 loss=0.0649
# Epoch=9 loss=0.0524
# Epoch=10 loss=0.0415
# Epoch=1 loss=0.4455
# Epoch=2 loss=0.2381
# Epoch=3 loss=0.1742
# Epoch=4 loss=0.1341
# Epoch=5 loss=0.1055
# Epoch=6 loss=0.0835
# Epoch=7 loss=0.0661
# Epoch=8 loss=0.0518
# Epoch=9 loss=0.0402
# Epoch=10 loss=0.0322
# Epoch=1 loss=1.3446
# Epoch=2 loss=0.8152
# Epoch=3 loss=0.6907
# Epoch=4 loss=0.6293
# Epoch=5 loss=0.5913
# Epoch=6 loss=0.5635
# Epoch=7 loss=0.5427
# Epoch=8 loss=0.5249
# Epoch=9 loss=0.5106
# Epoch=10 loss=0.4974
# Optimizer "<class 'torch.optim.adam.Adam'>" has accuracy 0.9005
# Optimizer "<class 'torch.optim.rmsprop.RMSprop'>" has accuracy 0.8982
# Optimizer "<class 'torch.optim.adagrad.Adagrad'>" has accuracy 0.7201

# %% [markdown]
# ### Задание 7. Реализация ReLU
#
# **4** балла
#
# Самостоятельно реализуйте функцию активации ReLU.
# Замените в уже обученной модели функцию активации на вашу. Убедитесь что ничего не изменилась.

# %%
class CustomReLU(nn.Module):     
    def __init__(self):
        super().__init__()

    def forward(self, x):
        # YOUR CODE HERE
        # если элемент x < 0, то 0, если >= 0, то x
        x[x < 0] = 0
        return x

# %% [markdown]
# Заново обучите модель и проверьте правильность реализации `CustomReLU`.

# %%
fc_net = FCNet(activation = CustomReLU())
loss_function = nn.CrossEntropyLoss()
lr = 0.001
optimizer = torch.optim.Adam(fc_net.parameters(), lr=3e-4)

n_epochs = 10
loss_history = []

for epoch in range(n_epochs):
    epoch_loss = 0
    for images, labels in trainloader: 
        optimizer.zero_grad() 
        outputs = fc_net(images) 
        loss = loss_function(outputs, labels) 
        loss.backward() 
        optimizer.step() 

        epoch_loss += loss.item()

    loss_history.append(epoch_loss/len(trainloader))

    print(f"Epoch={epoch+1} loss={loss_history[epoch]:.4f}")

get_accuracy(fc_net, testloader)
# Out:
# Epoch=1 loss=0.6878
# Epoch=2 loss=0.3079
# Epoch=3 loss=0.2289
# Epoch=4 loss=0.1796
# Epoch=5 loss=0.1437
# Epoch=6 loss=0.1173
# Epoch=7 loss=0.0955
# Epoch=8 loss=0.0788
# Epoch=9 loss=0.0638
# Epoch=10 loss=0.0521
# 0.8943

# %% [markdown]
# Accuracy изменилось, но не значительно, но оно вообще скачет постоянно, так что все хорошо, вроде

# %% [markdown]
# ### Задание 8. Генерация картинок
#
# **3** балла
#
# Так как вы снова работаете в командах, то придумайте 3 предложения и сгенерируйте при помощи них 3 картинки, используя телеграм бота [ruDALLE](https://t.me/sber_rudalle_xl_bot). Прикрепите сюда ваши картины.

# %% [markdown]
# ![pic1](pic1.png)
# ![pic2](pic2.png)
# ![pic3](pic3.png)
